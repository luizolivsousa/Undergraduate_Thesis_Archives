# %%
import os
import pandas as pd

class BarData:
    def __init__(self, file_name):
        self.file_name = file_name
        self.df = self.read_csv(file_name)

    def read_csv(self, file_name):
        df = pd.read_csv(file_name, delimiter= ';', header= None)
        return df
    
    def __repr__(self) -> str:
        return f'{self.file_name}'


folder_path = r'PVs_csvs'

bar_objects = []

for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        bar = BarData(file_path)

        bar_objects.append(bar)

# %%
bar_objects
# Out:
# [PVs_csvs\10012 LECHUG-AM500.csv,
#  PVs_csvs\10110 LECHUG-AM230.csv,
#  PVs_csvs\10111 LECHUG-AM138.csv,
#  PVs_csvs\10120 LECHU1-AM000.csv,
#  PVs_csvs\10130 LECHU1-AM000.csv,
#  PVs_csvs\10132 LECHU3-AM000.csv,
#  PVs_csvs\10300 APAREC-AM069.csv,
#  PVs_csvs\10306 IRANDU-AM138.csv,
#  PVs_csvs\10308 PARQ10-AM138.csv,
#  PVs_csvs\10310 DI-4---AM138.csv,
#  PVs_csvs\10312 RIOPTE-AM138.csv,
#  PVs_csvs\10313 AMAZON-AM138.csv,
#  PVs_csvs\10320 MAUAB1-AM069.csv,
#  PVs_csvs\10325 MAUAB2-AM069.csv,
#  PVs_csvs\10335 MAUA2M-AM069.csv,
#  PVs_csvs\10344 CONSE1-AM069.csv,
#  PVs_csvs\10345 CONSE2-AM069.csv,
#  PVs_csvs\10350 CACHO2-AM069.csv,
#  PVs_csvs\10351 CACHO1-AM069.csv,
#  PVs_csvs\10361 JTEIX1-AM000.csv,
#  PVs_csvs\10362 JTEIX2-AM000.csv,
#  PVs_csvs\10363 JTEIX3-AM000.csv,
#  PVs_csvs\10364 JTEIX4-AM000.csv,
#  PVs_csvs\10369 JTEIX5-AM000.csv,
#  PVs_csvs\10370 FLORES-AM069.csv,
#  PVs_csvs\10379 AMBEV--AM069.csv,
#  PVs_csvs\10380 PNEGRA-AM069.csv,
#  PVs_csvs\10384 MAU3-4-AM000.csv,
#  PVs_csvs\10390 PIEPNG-AM069.csv,
#  PVs_csvs\10391 PIEPNGUTE013.csv,
#  PVs_csvs\10393 PISMAE-AM069.csv,
#  PVs_csvs\10394 SHOPMA-AM069.csv,
#  PVs_csvs\10395 SERING-AM069.csv,
#  PVs_csvs\10400 MANAUS-AM230.csv,
#  PVs_csvs\10401 MANA1A-AM069.csv,
#  PVs_csvs\10402 MANAU2-AM069.csv,
#  PVs_csvs\10405 CROCHA-AM230.csv,
#  PVs_csvs\10406 CROCHAUTE013.csv,
#  PVs_csvs\10410 BALBIN-AM230.csv,
#  PVs_csvs\10411 BALBI1UHE013.csv,
#  PVs_csvs\10416 P.FIG.-AM069.csv,
#  PVs_csvs\10417 P.FIG.-AM069.csv,
#  PVs_csvs\10418 P.FIG.-AM013.csv,
#  PVs_csvs\10419 P.FIG.-AM230.csv,
#  PVs_csvs\10420 DISTR1-AM069.csv,
#  PVs_csvs\10421 CESPEC-AM069.csv,
#  PVs_csvs\10422 MANA-1-AM000.csv,
#  PVs_csvs\10424 MANA-2-AM000.csv,
#  PVs_csvs\10426 MANA-3-AM000.csv,
#  PVs_csvs\10428 MANA-4-AM000.csv,
#  PVs_csvs\10430 CIDNOV-AM069.csv,
#  PVs_csvs\10440 DISTR2-AM069.csv,
#  PVs_csvs\10445 TAMBAQ-AM069.csv,
#  PVs_csvs\10447 PIETBQUTE013.csv,
#  PVs_csvs\10450 SJOSE--AM069.csv,
#  PVs_csvs\10451 PLACIB-AM069.csv,
#  PVs_csvs\10460 STOANT-AM069.csv,
#  PVs_csvs\10466 SIVAM--AM069.csv,
#  PVs_csvs\10480 MANACA-AM069.csv,
#  PVs_csvs\10485 IRANDU-AM069.csv,
#  PVs_csvs\10490 REDENC-AM069.csv,
#  PVs_csvs\10492 MARAPA-AM069.csv,
#  PVs_csvs\10500 MAUA-3-AM230.csv,
#  PVs_csvs\10504 MAUA-3-AM138.csv,
#  PVs_csvs\10505 MAUA-3-AM069.csv,
#  PVs_csvs\10509 MUBL4M-AM069.csv,
#  PVs_csvs\10510 J.TEIX-AM230.csv,
#  PVs_csvs\10511 J.TEIX-AM138.csv,
#  PVs_csvs\10513 MUBL4D-AM069.csv,
#  PVs_csvs\10520 MUTIRA-AM138.csv,
#  PVs_csvs\10530 CGRAND-AM138.csv,
#  PVs_csvs\10540 COMPEN-AM138.csv,
#  PVs_csvs\10545 CENTRO-AM138.csv,
#  PVs_csvs\10550 DISTR3-AM138.csv,
#  PVs_csvs\10700 JARAQ2-AM138.csv,
#  PVs_csvs\10755 AE-SB5-AM230.csv]
